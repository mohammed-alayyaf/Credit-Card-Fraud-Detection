# %% [markdown]
# ## Importing Needed Libraries & Loading the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/malayyaf/Desktop/Udacity - MLND/Credit Card Fraud Detection - Capstone Project/creditcard.csv")

# %% [markdown]
# ## EDA and Data Exploration

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
pd.value_counts(data['Class'], sort = True).sort_index().plot(kind = 'bar')
plt.title("Fraud class histogram")
plt.xlabel("Class")
plt.ylabel("Frequency")
print('Count of Normal Transactions:', len(data[data.Class==0]))
print('Count of Fradulant Transactions:', len(data[data.Class==1]))
# Out:
# Count of Normal Transactions: 284315
# Count of Fradulant Transactions: 492

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(15,8))

bins = 50

ax1.hist(data.Time[data.Class == 1], bins = bins, color = 'deeppink')
ax1.set_title('Fraud')

ax2.hist(data.Time[data.Class == 0], bins = bins, color = 'deepskyblue')
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Number of Transactions')
plt.show()

# %%
plt.figure(figsize = (12, 6))
ax = sns.boxplot(x = 'Class', y = 'Amount', data = data)
ax.set_ylim([0, 300])
plt.title('Boxplot Amount vs Class')
plt.show()

# %% [markdown]
# ## Preprocessing

# %%
# Normalizing 'Amount' Variable
from sklearn.preprocessing import StandardScaler
data['normAmount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1,1))

# %%
# Drop useless variables
data = data.drop(['Amount','Time'],axis=1)
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10     ...           V21       V22       V23  \
# 0  0.098698  0.363787  0.090794     ...     -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974     ...     -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643     ...      0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952     ...     -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074     ...     -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Class  normAmount
# ...

# %%
# creating new under-sampled dataset, where both classses will be equal in size

# shuffle the data before creating the subsamples, to ensure minimum information loss from deleting the instances of the over-represented class
data = data.sample(frac=1)

# amount of fraud classes 492 rows.
fraud_data = data.loc[data['Class'] == 1]
non_fraud_data = data.loc[data['Class'] == 0][:492]

normal_distributed_data = pd.concat([fraud_data, non_fraud_data])

# Shuffle dataframe rows
new_data = normal_distributed_data.sample(frac=1, random_state=42)

new_data.head()
# Out:
#                V1         V2         V3         V4         V5        V6  \
# 103391   1.230472  -0.186091   0.312794  -0.191389  -0.401300 -0.192658
# 255403   1.170756   2.501038  -4.986159   5.374160   0.997798 -1.259004
# 22684    1.118299  -1.787767   0.610174  -1.031252  -1.753969  0.222452
# 9509    -4.710529   8.636214 -15.496222  10.313349  -4.351341 -3.322689
# 152295 -17.537592  12.352519 -20.134613  11.122771 -14.571080 -0.381622
#
#                V7        V8        V9        V10     ...           V21  \
# 103391  -0.322468  0.074831  0.192974   0.011402     ...     -0.238512
# 255403  -1.237689  0.358426 -2.612489  -3.064730     ...      0.123145
# 22684   -1.124753  0.023337 -1.408254   1.244890     ...     -0.146298
# 9509   -10.788373  5.060381 -5.689311 -11.712187     ...      1.990545
# 152295 -23.928661 -4.724921 -8.603038 -15.231833     ...     -4.352213
#
#              V22       V23       V24       V25       V26       V27       V28  \
# ...

# %% [markdown]
# ## Model Building

# %%
import sklearn

print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.19.1.

# %%
# Define X(Features) & y(Label) 

X = data.drop('Class', axis=1)
y = data['Class']

# %%
# Train, Test split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 0)

# %%
# First we will test with Decision Tree
from sklearn.tree import DecisionTreeClassifier  
from sklearn.model_selection import GridSearchCV

dt_classifier = DecisionTreeClassifier()  

# Find the best parameters : recall optimisation
param_grid = {"criterion": ["gini", "entropy"], "max_depth": list(range(2,4,1)), 
              "min_samples_leaf": list(range(5,7,1))}

dt_classifier_gs = GridSearchCV(estimator = dt_classifier, param_grid = param_grid , scoring = 'recall')

dt_classifier_gs.fit(X_train, y_train)
best_parameters = dt_classifier_gs.best_estimator_
print('The best parameters for using this model is', best_parameters)
y_pred = dt_classifier_gs.predict(X_test)
# Out:
# The best parameters for using this model is DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Evaluating Decision Tree Classifier
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     85301
#           1       0.83      0.82      0.82       142
#
# avg / total       1.00      1.00      1.00     85443

# %%
from sklearn.linear_model import LogisticRegression

log_cfl = LogisticRegression()

log_cfl.fit(X_train, y_train)

param_grid = {
            'penalty' : ['l1','l2'], 
            'class_weight' : ['balanced', None], 
            'C' : [0.1, 1, 10, 100]
            }

CV_log_cfl = GridSearchCV(estimator = log_cfl, param_grid = param_grid , scoring = 'recall', verbose = 1, n_jobs = -1)
CV_log_cfl.fit(X_train, y_train)

best_parameters = CV_log_cfl.best_params_
print('The best parameters for using this model is', best_parameters)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed: 13.0min finished
# The best parameters for using this model is {'C': 0.1, 'class_weight': 'balanced', 'penalty': 'l1'}

# %%
log_cfl = LogisticRegression(C= 0.1, class_weight= 'balanced', penalty= 'l1')
log_cfl.fit(X_train, y_train)
y_pred = log_cfl.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      0.98      0.99     85301
#           1       0.06      0.92      0.12       142
#
# avg / total       1.00      0.98      0.99     85443

# %% [markdown]
# ### Model Enhancment

# %%
# Define X(Features) & y(Label) 

X = new_data.drop('Class', axis=1)
y = new_data['Class']

# %%
# Train, Test split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 0)

# %%
# First we will test with Decision Tree
from sklearn.tree import DecisionTreeClassifier  
from sklearn.model_selection import GridSearchCV

dt_classifier = DecisionTreeClassifier()  

# Find the best parameters : recall optimisation
param_grid = {"criterion": ["gini", "entropy"], "max_depth": list(range(2,4,1)), 
              "min_samples_leaf": list(range(5,7,1))}

dt_classifier_gs = GridSearchCV(estimator = dt_classifier, param_grid = param_grid , scoring = 'recall')

dt_classifier_gs.fit(X_train, y_train)
best_parameters = dt_classifier_gs.best_estimator_
print('The best parameters for using this model is', best_parameters)
y_pred = dt_classifier_gs.predict(X_test)
# Out:
# The best parameters for using this model is DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Evaluating Decision Tree Classifier
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.92      0.92      0.92       155
#           1       0.91      0.91      0.91       141
#
# avg / total       0.92      0.92      0.92       296

# %%
from sklearn.linear_model import LogisticRegression

log_cfl = LogisticRegression()

log_cfl.fit(X_train, y_train)

param_grid = {
            'penalty' : ['l1','l2'], 
            'class_weight' : ['balanced', None], 
            'C' : [0.1, 1, 10, 100]
            }

CV_log_cfl = GridSearchCV(estimator = log_cfl, param_grid = param_grid , scoring = 'recall', verbose = 1, n_jobs = -1)
CV_log_cfl.fit(X_train, y_train)

best_parameters = CV_log_cfl.best_params_
print('The best parameters for using this model is', best_parameters)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# The best parameters for using this model is {'C': 100, 'class_weight': 'balanced', 'penalty': 'l1'}
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    6.1s finished

# %%
log_cfl = LogisticRegression(C= 0.1, class_weight= 'balanced', penalty= 'l1')
log_cfl.fit(X_train, y_train)
y_pred = log_cfl.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.92      0.99      0.96       155
#           1       0.99      0.91      0.95       141
#
# avg / total       0.96      0.95      0.95       296
